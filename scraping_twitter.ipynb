# %% [markdown]
# <a href="https://colab.research.google.com/github/fiqram-cell/scraping-twitter/blob/main/scraping_twitter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
twitter_auth_token = '4ddfe59ed485308a713a22f022794fe6c1c15c0e'

# !pip install pandas

# !sudo apt-get update
# !sudo apt-get install -y ca-certificates curl gnupg
# !sudo mkdir -p /etc/apt/keyrings
# !curl -fsSL https://deb.nodesource.com/gpgkey/nodesource-repo.gpg.key | sudo gpg --dearmor -o /etc/apt/keyrings/nodesource.gpg
# !NODE_MAJOR=20 && echo "deb [signed-by=/etc/apt/keyrings/nodesource.gpg] https://deb.nodesource.com/node_$NODE_MAJOR.x nodistro main" | sudo tee /etc/apt/sources.list.d/nodesource.list
# !sudo apt-get update
# !sudo apt-get install nodejs -y
# !node -v
# Out:
# ...
# Hit:1 https://cli.github.com/packages stable InRelease
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Hit:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:5 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:6 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:7 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:11 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:12 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [9,278 kB]
# ...

# %%
# Crawl Data
filename = "beasiswaa.csv"
search_keyword = "(beasiswa OR info beasiswa OR pendaftaran beasiswa OR pengumuman beasiswa) since:2025-01-01 until:2025-05-30 lang:id"
limit = 2000

# !npx tweet-harvest@2.6.1 -o "{filename}" -s "{search_keyword}" --tab "LATEST" -l {limit} --token {twitter_auth_token}
# Out:
# ⠙⠹⠸⠼⠴Tweet Harvest [v2.6.1]
#
# Research by Helmi Satria
# Use it for Educational Purposes only!
#
# This script uses Chromium Browser to crawl data from Twitter with your Twitter auth token.
# Please enter your Twitter auth token when prompted.
#
# Note: Keep your access token secret! Don't share it with anyone else.
# Note: This script only runs on your local device.
#
#
# Opening twitter search page...
#
#
# -- Scrolling... (1)
# Filling in keywords: (beasiswa OR info beasiswa OR pendaftaran beasiswa OR pengumuman beasiswa) since:2025-01-01 until:2025-05-30 lang:id
#
#  (2)
#
# Your tweets saved to: /content/tweets-data/beasiswaa.csv
# Total tweets saved: 20
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/beasiswaa.csv
# Total tweets saved: 40
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/beasiswaa.csv
# Total tweets saved: 60
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/beasiswaa.csv
# ...

# %%
import pandas as pd
file = f"tweets-data/{filename}"
dframe = pd.read_csv(file, delimiter=",")
display(dframe)
# Out:
#       conversation_id_str                      created_at  favorite_count  \
# 0     1928238719477096793  Thu May 29 23:55:10 +0000 2025             823
# 1     1928074625331728608  Thu May 29 23:54:48 +0000 2025               0
# 2     1928238198112604651  Thu May 29 23:53:06 +0000 2025               0
# 3     1928074625331728608  Thu May 29 23:51:59 +0000 2025               0
# 4     1928213686457618612  Thu May 29 23:49:30 +0000 2025               1
# ...                   ...                             ...             ...
# 1997  1926084728043565137  Sat May 24 09:46:26 +0000 2025               1
# 1998  1926162376794997241  Sat May 24 09:45:20 +0000 2025               0
# 1999  1926212067960168479  Sat May 24 09:41:58 +0000 2025               0
# 2000  1926211501766983925  Sat May 24 09:39:43 +0000 2025               0
# 2001  1925869014703558979  Sat May 24 09:30:20 +0000 2025               0
#
#                                               full_text               id_str  \
# ...

# %%
from google.colab import files
nama_file = 'beasiswaa.csv'
dframe.to_csv(nama_file, index=False)
print(nama_file)
files.download(nama_file)
# Out:
# beasiswaa.csv
